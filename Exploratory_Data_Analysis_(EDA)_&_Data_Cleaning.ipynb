# %% [markdown]
# # Exploratory Data Analysis
#
# - Missing/Null Values
# - Typo Errors
# - Unsorted Data
# - Duplicated Data
# - Invalid (Not possible) & Innaccurate (Not Exact) Values
# - Wrong Data Type
# - Wrong Column Names
# - Correct column name but difficult to understand
# - Inconsistency due to unit of measure
# - Inconsistency across columns
# - Anomalies/extreme values/Outliers
# - Transformations in Data
# - Feature Engineering

# %%
#load the libraries
import pandas as pd
import numpy as np

# %%
#from google.colab import files
#uploaded=files.upload()
data=pd.read_csv("C:/Users/91637/OneDrive/Desktop/Git Push/Weather EDA Excelar.csv")
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
#To drop the first column 'Unnamed: 0' from the data, because we have default python indexation.
data.drop('Unnamed: 0',axis=1,inplace=True)
data
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     67     5    1  2010    67       S
# 1     36.0    118.0   8.0     72     5    2  2010    72       C
# 2     12.0    149.0  12.6     74     5    3  2010    74      PS
# 3     18.0    313.0  11.5     62     5    4  2010    62       S
# 4      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     67     5    1  2010    67       C
# 154   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155    NaN    145.0  13.2     77     9   27  2010    77       S
# 156   14.0    191.0  14.3     75     9   28  2010    75       S
# 157   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
#To check the list of variables/columns, and their data types, and count of non-missing data in each column
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   158 non-null    object
#  4   Month    158 non-null    object
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 11.2+ KB

# %%
#data.describe(include='all'), for a brief statistical summary
data.describe()
# Out:
#             Ozone     Solar.R        Wind         Day    Year        Temp
# count  120.000000  151.000000  158.000000  158.000000   158.0  158.000000
# mean    41.583333  185.403974    9.957595   16.006329  2010.0   77.727848
# std     32.620709   88.723103    3.511261    8.997166     0.0    9.377877
# min      1.000000    7.000000    1.700000    1.000000  2010.0   56.000000
# 25%     18.000000  119.000000    7.400000    8.000000  2010.0   72.000000
# 50%     30.500000  197.000000    9.700000   16.000000  2010.0   78.500000
# 75%     61.500000  257.000000   11.875000   24.000000  2010.0   84.000000
# max    168.000000  334.000000   20.700000   31.000000  2010.0   97.000000

# %%
#Shape of the data gives us the number of rows & columns in the data
print(type(data))
data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 9)

# %% [markdown]
# # 'Temp C' & 'Month' column shows 'object' data type. Why?

# %%
#To find the unique values in 'Temp C'
data['Temp C'].unique()
# Out:
# array(['67', '72', '74', '62', '56', '66', '65', '59', '61', '69', 'C',
#        '68', '58', '64', '57', '73', '81', '79', '76', '78', '84', '85',
#        '82', '87', '90', '93', '92', '80', '77', '75', '83', '88', '89',
#        '91', '86', '97', '94', '96', '71', '63', '70'], dtype=object)

# %%
set(data['Temp C'])
# Out:
# {'56',
#  '57',
#  '58',
#  '59',
#  '61',
#  '62',
#  '63',
#  '64',
#  '65',
#  '66',
#  '67',
#  '68',
#  '69',
#  '70',
#  '71',
#  '72',
#  '73',
#  '74',
#  '75',
#  '76',
#  '77',
#  '78',
#  '79',
#  '80',
#  '81',
#  '82',
#  '83',
#  '84',
#  '85',
#  '86',
#  '87',
#  '88',
#  '89',
#  '90',
#  '91',
#  '92',
#  '93',
#  '94',
#  '96',
#  '97',
#  'C'}

# %%
sorted(data['Temp C'].unique())
# Out:
# ['56',
#  '57',
#  '58',
#  '59',
#  '61',
#  '62',
#  '63',
#  '64',
#  '65',
#  '66',
#  '67',
#  '68',
#  '69',
#  '70',
#  '71',
#  '72',
#  '73',
#  '74',
#  '75',
#  '76',
#  '77',
#  '78',
#  '79',
#  '80',
#  '81',
#  '82',
#  '83',
#  '84',
#  '85',
#  '86',
#  '87',
#  '88',
#  '89',
#  '90',
#  '91',
#  '92',
#  '93',
#  '94',
#  '96',
#  '97',
#  'C']

# %%
data[data['Temp C']=='C']
# Out:
#     Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 10    7.0      NaN   6.9      C     5   11  2010    74       C

# %%
#To find the unique values in 'Month'
sorted(data['Month'].unique())
# Out:
# ['5', '6', '7', '8', '9', 'May']

# %%
#Finding the row which has the invalid data type
data[data['Month']=='May']
# Out:
#     Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 23   32.0     92.0  12.0     61   May   24  2010    61       C

# %%
#Replacing an invalid value with the appropriate value
data['Month']=data['Month'].replace('May',5)
data['Month'].unique()
# Out:
# array(['5', 5, '6', '7', '8', '9'], dtype=object)

# %%
data.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp C      object
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
#Optional codes - Use them according to requirement
data['Month_1']=data['Month'].replace({'5':'May','6':'June','7':'July','8':'August','9':'September'})
data['Month_2']=data['Month'].replace({'May':5,'June':6,'July':7,'August':8,'September':9})
data

# %%
data.drop(['Month_1','Month_2'],axis=1,inplace=True)
data.head()

# %%
data['Weather'].unique()
# Out:
# array(['S', 'C', 'PS', nan], dtype=object)

# %% [markdown]
# # Data Conversion

# %%
#errors=coerce will introduce NA values for non numeric data in the columns
data['Month']=pd.to_numeric(data['Month'],errors='coerce')
data['Temp C']=pd.to_numeric(data['Temp C'],errors='coerce')

# %%
data['Month'].unique()
# Out:
# array([5, 6, 7, 8, 9])

# %%
data['Temp C'].unique()
# Out:
# array([67., 72., 74., 62., 56., 66., 65., 59., 61., 69., nan, 68., 58.,
#        64., 57., 73., 81., 79., 76., 78., 84., 85., 82., 87., 90., 93.,
#        92., 80., 77., 75., 83., 88., 89., 91., 86., 97., 94., 96., 71.,
#        63., 70.])

# %%
#After converting the 'Temp C' & 'Month' columns to numeric, we are cross-checking the data types
data.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp C     float64
# Month        int64
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
data1=data.copy()

# %% [markdown]
# The method .copy() is used here so that any changes made in new DataFrame don't get reflected in the original one

# %% [markdown]
# # Duplicates

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156     True
# 157    False
# Length: 158, dtype: bool

# %%
#Print the duplicated rows
data[data.duplicated()]
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3     75     9   28  2010    75       S

# %%
data[(data['Solar.R']==191)]
data[(data['Ozone']==14)]
#data[(data['Day']==28)]
data[(data['Solar.R']==191) & (data['Ozone']==14)]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    75.0      9   28  2010    75       S
# 156   14.0    191.0  14.3    75.0      9   28  2010    75       S

# %%
#To check which of the rows are duplicated
data[(data['Solar.R']==191) & (data['Ozone']==14)]

# %%
#To drop all duplicated rows
data=data.drop_duplicates()
#If you want to drop a particular duplicated row, but not all duplicated rows, then
#data.drop(156, axis=0,inplace =True)

# %%
#After dropping duplicates, we do not see any rows when we call for duplicate rows
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar.R, Wind, Temp C, Month, Day, Year, Temp, Weather]
# Index: []

# %%
#After dropping duplicates, number of rows & number of columns are as below:
data.shape
# Out:
# (157, 9)

# %% [markdown]
# # Drop duplicate columns

# %%
data[['Temp C','Temp']].head()
# Out:
#    Temp C  Temp
# 0    67.0    67
# 1    72.0    72
# 2    74.0    74
# 3    62.0    62
# 4    56.0    56

# %%
#To check which rows in 'Temp C' & 'Temp', have different values
data[data['Temp C']!=data['Temp']]
# Out:
#     Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 10    7.0      NaN   6.9     NaN      5   11  2010    74       C

# %%
data.drop('Temp C',axis=1,inplace=True)
#data=data.drop('Temp C',axis=1)
data
# Out:
# <ipython-input-30-3e6e19b8061b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('Temp C',axis=1,inplace=True)
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      5    1  2010    67       S
# 1     36.0    118.0   8.0      5    2  2010    72       C
# 2     12.0    149.0  12.6      5    3  2010    74      PS
# 3     18.0    313.0  11.5      5    4  2010    62       S
# 4      NaN      NaN  14.3      5    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5      9   30  2010    68       S
# 153   41.0    190.0   7.4      5    1  2010    67       C
# 154   30.0    193.0   6.9      9   26  2010    70      PS
# 155    NaN    145.0  13.2      9   27  2010    77       S
# ...

# %%
data[["Year","Month","Day"]]
# Out:
#      Year  Month  Day
# 0    2010      5    1
# 1    2010      5    2
# 2    2010      5    3
# 3    2010      5    4
# 4    2010      5    5
# ..    ...    ...  ...
# 152  2010      9   30
# 153  2010      5    1
# 154  2010      9   26
# 155  2010      9   27
# 157  2010      9   29
#
# [157 rows x 3 columns]

# %%
#Creating date column using the year, month & day columns
a=["Year","Month","Day"]
data['Date']=data[a].apply(lambda x:'-'.join(x.values.astype(str)),axis="columns")
print(data.dtypes)
data['Date']=pd.to_datetime(data['Date'])
print(data.dtypes)
data[0:5]
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month        int64
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# Date        object
# dtype: object
# Ozone             float64
# Solar.R           float64
# Wind              float64
# Month               int64
# Day                 int64
# Year                int64
# Temp                int64
# Weather            object
# Date       datetime64[ns]
# dtype: object
# <ipython-input-32-6a780ad6c767>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Date']=data[a].apply(lambda x:'-'.join(x.values.astype(str)),axis="columns")
# <ipython-input-32-6a780ad6c767>:5: SettingWithCopyWarning:
# ...

# %%
import datetime as dt
data['Weekday'] = data['Date'].dt.strftime('%A')
data['Month_Words'] = data['Date'].dt.strftime('%B')
data
# Out:
# <ipython-input-33-58dd4de91a1e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Weekday'] = data['Date'].dt.strftime('%A')
# <ipython-input-33-58dd4de91a1e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Month_Words'] = data['Date'].dt.strftime('%B')
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather       Date  \
# 0     41.0    190.0   7.4      5    1  2010    67       S 2010-05-01
# 1     36.0    118.0   8.0      5    2  2010    72       C 2010-05-02
# ...

# %%
#Creating date column using the year, month & day columns
data['Date']=data[["Year","Month","Day"]].apply(lambda x:'-'.join(x.values.astype(str)),axis="columns")
print(data.dtypes)
data['Date']=pd.to_datetime(data['Date'])
print(data.dtypes)
data[0:5]

# %%
data['Year'].unique()
# Out:
# array([2010])

# %%
data.drop('Year',axis=1,inplace=True)
data
# Out:
# <ipython-input-35-6d8ccf2fa5ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('Year',axis=1,inplace=True)
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather       Date    Weekday  \
# 0     41.0    190.0   7.4      5    1    67       S 2010-05-01   Saturday
# 1     36.0    118.0   8.0      5    2    72       C 2010-05-02     Sunday
# 2     12.0    149.0  12.6      5    3    74      PS 2010-05-03     Monday
# 3     18.0    313.0  11.5      5    4    62       S 2010-05-04    Tuesday
# 4      NaN      NaN  14.3      5    5    56       S 2010-05-05  Wednesday
# ..     ...      ...   ...    ...  ...   ...     ...        ...        ...
# 152   20.0    223.0  11.5      9   30    68       S 2010-09-30   Thursday
# ...

# %%
#To filter a date component from a date type column
data.loc[data['Date'].dt.month==6]

# %% [markdown]
# # Rename the columns

# %%
data.columns
# Out:
# Index(['Ozone', 'Solar.R', 'Wind', 'Month', 'Day', 'Temp', 'Weather', 'Date',
#        'Weekday', 'Month_Words'],
#       dtype='object')

# %%
#rename the Solar column
data.rename({'Solar.R': 'Solar_Radiation','Temp':'Temp_F'}, axis=1, inplace=True)
data[0:5]
# Out:
# <ipython-input-40-33089fb4650a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename({'Solar.R': 'Solar_Radiation','Temp':'Temp_F'}, axis=1, inplace=True)
#    Ozone  Solar_Radiation  Wind  Month  Day  Temp_F Weather       Date  \
# 0   41.0            190.0   7.4      5    1      67       S 2010-05-01
# 1   36.0            118.0   8.0      5    2      72       C 2010-05-02
# 2   12.0            149.0  12.6      5    3      74      PS 2010-05-03
# 3   18.0            313.0  11.5      5    4      62       S 2010-05-04
# 4    NaN              NaN  14.3      5    5      56       S 2010-05-05
#
#      Weekday Month_Words
# 0   Saturday         May
# 1     Sunday         May
# 2     Monday         May
# 3    Tuesday         May
# 4  Wednesday         May

# %% [markdown]
# # Outlier Detection

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# histogram of Ozone
data['Ozone'].hist()

#Ozone is right-skewed data, so we can expect outliers on the higher side
# Out:
# <Axes: >

# %%
#Box plot
data.boxplot(column=['Ozone'],grid=True)

#There are 2 outliers in Ozone, also Ozone data is ratio scaled, since ozone cannot be negative value.
# Out:
# <Axes: >

# %%
data[data['Ozone']>125]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather       Date    Weekday  \
# 61   135.0    269.0   4.1      7    1    84       S 2010-07-01   Thursday
# 116  168.0    238.0   3.4      8   25    81      PS 2010-08-25  Wednesday
#
#     Month_Words
# 61         July
# 116      August

# %%
#Descriptive stats
data['Ozone'].describe()

# %%
#Quartile 1
print('Quartile 1 : ',data['Ozone'].quantile(0.25))

#Quartile 3
print('Quartile 3 : ',data['Ozone'].quantile(0.75))

# %%
#Interquartile Range
print('Inter-Quartile Range : ',62-18)

#Upper Limit of Ozone
print('Upper Limit : ',62+1.5*(62-18))

#Lower Limit of Ozone
print('Lower Limit : ',18-1.5*(62-18))

# %%
Ozone_Outliers=data[(data['Ozone'] > 128) | (data['Ozone'] < -48)]
Ozone_Outliers

# %%
data.describe()

# %%
#Outlier Detection for all columns
Num_Columns= ['Ozone','Solar_Radiation','Wind','Temp_F']
for i in Num_Columns:
  column_name = i
  print("Outliers calculation for", i)
  #print(data.boxplot(column=[column_name],grid=True))
  print(data[column_name].describe())
#Quartile 1
  Q1=data[column_name].quantile(0.25)
  print('Quartile 1 : ',Q1)
#Quartile 3
  Q3=data[column_name].quantile(0.75)
  print('Quartile 3 : ',Q3)
#Interquartile Range
  IQR= Q3 - Q1
  print('Inter-Quartile Range : ',IQR)
#Upper Limit
  UL = Q3 + (1.5 * IQR)
  print('Upper Limit : ',UL)
#Lower Limit
  LL = Q1 - (1.5 * IQR)
  print('Lower Limit : ', LL)
  Outliers=data[(data[column_name] > UL) | (data[column_name] < LL)]
  print('The Outliers for column',i, 'are:')
  print(Outliers)
  print('__________________________________________________________')
# Out:
# Outliers calculation for Ozone
# count    119.000000
# mean      41.815126
# std       32.659249
# min        1.000000
# 25%       18.000000
# 50%       31.000000
# 75%       62.000000
# max      168.000000
# Name: Ozone, dtype: float64
# Quartile 1 :  18.0
# Quartile 3 :  62.0
# Inter-Quartile Range :  44.0
# Upper Limit :  128.0
# Lower Limit :  -48.0
# The Outliers for column Ozone are:
#      Ozone  Solar_Radiation  Wind  Month  Day  Temp_F Weather       Date  \
# 61   135.0            269.0   4.1      7    1      84       S 2010-07-01
# 116  168.0            238.0   3.4      8   25      81      PS 2010-08-25
#
#        Weekday Month_Words
# 61    Thursday        July
# 116  Wednesday      August
# __________________________________________________________
# Outliers calculation for Solar_Radiation
# count    150.000000
# mean     185.366667
# std       89.019146
# min        7.000000
# 25%      118.500000
# 50%      199.000000
# 75%      257.500000
# max      334.000000
# ...

# %%
#To check outliers in any categorical data
#If any category has only 1 frequency, we can consider that as an outlier.
data['Weather'].value_counts()
# Out:
# Weather
# S     58
# C     49
# PS    47
# Name: count, dtype: int64

# %%
#Bar plot
data['Weather'].value_counts().plot.bar()

# %%
data['Month'].value_counts()

# %%
data['Day'].value_counts()

# %%
Num_Columns= ['Ozone','Solar_Radiation','Wind','Temp_F']
for i in Num_Columns:
  print(i)
  print(min(data[i]),max(data[i]))
# Out:
# Ozone
# 1.0 168.0
# Solar_Radiation
# 7.0 334.0
# Wind
# 1.7 20.7
# Temp_F
# 56 97

# %%
#To check outliers in other variables
fig,axs=plt.subplots(1,4)
plt.subplots_adjust(left=0.9, right=1.8,bottom= 0.9, top=1.8,wspace = 0.5)
axs[0].boxplot(data['Wind'])
axs[0].set_xlim(0,25)
axs[0].set_title('Wind')
axs[1].boxplot(data['Solar_Radiation'])
axs[1].set_xlim(0,400)
axs[1].set_title('Solar_Radiation')
axs[2].boxplot(data['Temp_F'])
axs[2].set_xlim(0,100)
axs[2].set_title('Temp_F')
axs[3].boxplot(data['Ozone'])
axs[3].set_xlim(0,200)
axs[3].set_title('Ozone')
# Out:
# Text(0.5, 1.0, 'Ozone')

# %%
data

# %% [markdown]
# # Missing Values and Imputation

# %% [markdown]
# If the dataset is small, and only 3-5% data is missing from a specific numerical column, then it will be ideal to replace the missing values with either mean or median
# - Mean: If the data is normally distributed
# - Median: If the data is skewed
#
# If more than 60-70% is missing, then it will be ideal to drop the column, because imputing so much data is neither possible, nor appropriate.
#
# If data is missing upto 5% to 40%, then used advanced techniques.
# Either use linear regression, decision trees, or discretization

# %%
data.isnull().sum()
data.isna().sum()
# Out:
# Ozone              38
# Solar_Radiation     7
# Wind                0
# Month               0
# Day                 0
# Temp_F              0
# Weather             3
# Date                0
# Weekday             0
# Month_Words         0
# dtype: int64

# %%
print('The % of missing values in Ozone is', round((data['Ozone'].isnull().sum()/len(data))*100,1))
print('The % of missing values in Solar is', round((data['Solar_Radiation'].isnull().sum()/len(data))*100,1))
print('The % of missing values in Weather is', round((data['Weather'].isnull().sum()/len(data))*100,1))
# Out:
# The % of missing values in Ozone is 24.2
# The % of missing values in Solar is 4.5
# The % of missing values in Weather is 1.9

# %%
#(1-(data['Ozone'].count()/len(data)))*100

# %%
#(data['Ozone'].isnull().sum()/len(data))*100

# %%
import seaborn as sns
cols = data.columns
print(cols)
colours = ['Green','Red'] # specify the colours - Red is missing. Green is not missing.
sns.heatmap(data[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# Index(['Ozone', 'Solar_Radiation', 'Wind', 'Month', 'Day', 'Temp_F', 'Weather',
#        'Date', 'Weekday', 'Month_Words'],
#       dtype='object')
# <Axes: >

# %%
#colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
#sns.heatmap(data[cols].isnull(), cmap=sns.color_palette(colours))

# %%
sns.heatmap(data[cols].isnull())

# %%
#To check if 'Solar.R' column data is skewed
data['Solar_Radiation'].skew()
# Out:
# -0.4141167126969295

# %% [markdown]
# - Since only about 4.43% data is missing in 'Solar', we can replace the missing value with mean/median depending upon skewness in the data.
# - If data is skewed, then replace with median
# - If data is normally distributed, then replace with mean
#
# -1 -------- -0.5 -------- 0 -------- 0.5 -------- 1
#
# If skewness value is closer to -0.35 or less, OR 0.35 or more, then replace missing values with Median.
# If skewness value is more closer to 0, then replace missing values with Mean.
#
# Also if more than 5% data is missing, then it is NOT ideal to replace with a single value,
# we should look for similar cases in the data to impute the missing values.
#
# Suppose we consider 'Solar' column to be helpful in determining the missing values in Ozone, we must bin the Ozone data, and find the mean value of solar grouped by these bins.
#
# But 'Solar' column also has some missing data, so we need to impute those first if we want to use the 'Solar' column to impute missing values in 'Ozone' column.

# %%
data['Solar_Radiation'].hist(bins=8)
# Out:
# <Axes: >

# %%
solar_median=data['Solar_Radiation'].median()
print(solar_median)
solar_mean=data['Solar_Radiation'].mean()
print(solar_mean)
# Out:
# 199.0
# 185.36666666666667

# %% [markdown]
# The command below will replace all the missing values in the 'Solar' column by creating a new 'Solar_Full' column
#
# In the 'Solar_Full' column, non-missing data from 'Solar' will be as it is, whereas missing values of 'Solar' will be replaced with the Solar Median value.

# %%
#Using fillna, we are replacing the null values in Solar_Radiation with its median
#We are creating a new column 'Solar_Full' which has replaced median value for missing data, and non-missing data is intact.
data['Solar_Full'] = data['Solar_Radiation'].fillna(solar_median)
data[['Solar_Full','Solar_Radiation']]
# Out:
# <ipython-input-46-cdfbf3cde6ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Solar_Full'] = data['Solar_Radiation'].fillna(solar_median)
#      Solar_Full  Solar_Radiation
# 0         190.0            190.0
# 1         118.0            118.0
# 2         149.0            149.0
# 3         313.0            313.0
# 4         199.0              NaN
# ..          ...              ...
# 152       223.0            223.0
# 153       190.0            190.0
# 154       193.0            193.0
# 155       145.0            145.0
# 157       131.0            131.0
#
# [157 rows x 2 columns]

# %%
#To view all the rows where Solar_Radiation has a null value
data[data['Solar_Radiation'].isna()]
# Out:
#     Ozone  Solar_Radiation  Wind  Month  Day  Temp_F Weather       Date  \
# 4     NaN              NaN  14.3      5    5      56       S 2010-05-05
# 5    28.0              NaN  14.9      5    6      66       C 2010-05-06
# 10    7.0              NaN   6.9      5   11      74       C 2010-05-11
# 26    NaN              NaN   8.0      5   27      57      PS 2010-05-27
# 95   78.0              NaN   6.9      8    4      86     NaN 2010-08-04
# 96   35.0              NaN   7.4      8    5      85       S 2010-08-05
# 97   66.0              NaN   4.6      8    6      87       C 2010-08-06
#
#       Weekday Month_Words  Solar_Full
# 4   Wednesday         May       199.0
# 5    Thursday         May       199.0
# 10    Tuesday         May       199.0
# 26   Thursday         May       199.0
# 95  Wednesday      August       199.0
# 96   Thursday      August       199.0
# 97     Friday      August       199.0

# %% [markdown]
# The command below will replace all the missing values in the original 'Solar' column itself

# %%
data['Solar_Radiation'] = data['Solar_Radiation'].fillna(solar_median)
# Out:
# <ipython-input-48-75ba23c2267e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Solar_Radiation'] = data['Solar_Radiation'].fillna(solar_median)

# %%
data.isnull().sum()
# Out:
# Ozone              38
# Solar_Radiation     0
# Wind                0
# Month               0
# Day                 0
# Temp_F              0
# Weather             3
# Date                0
# Weekday             0
# Month_Words         0
# Solar_Full          0
# dtype: int64

# %%
data.drop('Solar_Full', axis=1, inplace=True)
data.head()
# Out:
# <ipython-input-50-2a1b157ab948>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('Solar_Full', axis=1, inplace=True)
#    Ozone  Solar_Radiation  Wind  Month  Day  Temp_F Weather       Date  \
# 0   41.0            190.0   7.4      5    1      67       S 2010-05-01
# 1   36.0            118.0   8.0      5    2      72       C 2010-05-02
# 2   12.0            149.0  12.6      5    3      74      PS 2010-05-03
# 3   18.0            313.0  11.5      5    4      62       S 2010-05-04
# 4    NaN            199.0  14.3      5    5      56       S 2010-05-05
#
#      Weekday Month_Words
# 0   Saturday         May
# 1     Sunday         May
# 2     Monday         May
# 3    Tuesday         May
# 4  Wednesday         May

# %%
#To check which rows have any missing value under any column
data[data.isnull().any(axis=1)]

# %%
len(data[data.isnull().any(axis=1)])

# %%
data[:3]

# %%
'''Since Ozone and Temp_F is most correlated as compared to other columns,
we can use the Temp_F data to impute Ozone missing data.'''
data.iloc[:,:6].corr()
# Out:
#                     Ozone  Solar_Radiation      Wind     Month       Day  \
# Ozone            1.000000         0.345610 -0.590270  0.149594 -0.025465
# Solar_Radiation  0.345610         1.000000 -0.057709 -0.083788 -0.156243
# Wind            -0.590270        -0.057709  1.000000 -0.170328  0.029900
# Month            0.149594        -0.083788 -0.170328  1.000000  0.041438
# Day             -0.025465        -0.156243  0.029900  0.041438  1.000000
# Temp_F           0.694404         0.256994 -0.441228  0.408060 -0.122787
#
#                    Temp_F
# Ozone            0.694404
# Solar_Radiation  0.256994
# Wind            -0.441228
# Month            0.408060
# Day             -0.122787
# Temp_F           1.000000

# %%
plt.scatter(data['Ozone'], data['Temp_F'])
plt.xlabel('Ozone')
plt.ylabel('Temperature in Fahrenheit')

# %% [markdown]
# # Correlation
# - If the correlation value is greater than 0.5 and closer to positive 1, then the variables are highly positively correlated.
# - If the correlation value is lesser than -0.5 and closer to negative 1, then the variables are highly negatively correlated.
# - If the correlation value is between -0.5 to +0.5, then the variables are moderately correlated.
#
# -1 -------- -0.5 -------- 0 -------- 0.5 -------- 1

# %%
#data['Temp_F'].describe()
print(min(data['Temp_F']))
print(max(data['Temp_F']))
# Out:
# 56
# 97

# %%
#data['Temp_F_Bin']=pd.cut(x=data['Temp_F'],bins=[55,65,75,85,95,105], right=True, labels=['a','b','c','d','e'])
#data.head()

# %%
#Discretization of the Temp Column
data['Temp_F_Bin']=pd.cut(x=data['Temp_F'],bins=np.arange(55,101,5),right=True,
                          labels=['55-60','60-65','65-70','70-75','75-80','80-85','85-90','90-95','95-100'])
data.head()
# Out:
# <ipython-input-52-9ccff5d7fc3c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Temp_F_Bin']=pd.cut(x=data['Temp_F'],bins=np.arange(55,101,5),right=True,
#    Ozone  Solar_Radiation  Wind  Month  Day  Temp_F Weather       Date  \
# 0   41.0            190.0   7.4      5    1      67       S 2010-05-01
# 1   36.0            118.0   8.0      5    2      72       C 2010-05-02
# 2   12.0            149.0  12.6      5    3      74      PS 2010-05-03
# 3   18.0            313.0  11.5      5    4      62       S 2010-05-04
# 4    NaN            199.0  14.3      5    5      56       S 2010-05-05
#
#      Weekday Month_Words Temp_F_Bin
# 0   Saturday         May      65-70
# 1     Sunday         May      70-75
# ...

# %%
data['Temp_F_Bin'].value_counts()
# Out:
# Temp_F_Bin
# 75-80     35
# 80-85     34
# 85-90     20
# 70-75     19
# 65-70     17
# 90-95     12
# 60-65     10
# 55-60      8
# 95-100     2
# Name: count, dtype: int64

# %%
data.groupby('Temp_F_Bin')['Ozone'].mean()
# Out:
# <ipython-input-54-a2b842e24c59>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby('Temp_F_Bin')['Ozone'].mean()
# Temp_F_Bin
# 55-60     11.000000
# 60-65     15.700000
# 65-70     24.466667
# 70-75     16.933333
# 75-80     32.857143
# 80-85     49.074074
# 85-90     73.176471
# 90-95     91.875000
# 95-100    80.000000
# Name: Ozone, dtype: float64

# %%
#Similar Case Mean
data['Ozone_Full'] = data['Ozone'].fillna(data.groupby('Temp_F_Bin')['Ozone'].transform('mean'))
# Out:
# <ipython-input-55-72e26ab23d8e>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data['Ozone_Full'] = data['Ozone'].fillna(data.groupby('Temp_F_Bin')['Ozone'].transform('mean'))
# <ipython-input-55-72e26ab23d8e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Ozone_Full'] = data['Ozone'].fillna(data.groupby('Temp_F_Bin')['Ozone'].transform('mean'))

# %%
data[['Ozone','Temp_F','Temp_F_Bin','Ozone_Full']]
# Out:
#      Ozone  Temp_F Temp_F_Bin  Ozone_Full
# 0     41.0      67      65-70   41.000000
# 1     36.0      72      70-75   36.000000
# 2     12.0      74      70-75   12.000000
# 3     18.0      62      60-65   18.000000
# 4      NaN      56      55-60   11.000000
# ..     ...     ...        ...         ...
# 152   20.0      68      65-70   20.000000
# 153   41.0      67      65-70   41.000000
# 154   30.0      70      65-70   30.000000
# 155    NaN      77      75-80   32.857143
# 157   18.0      76      75-80   18.000000
#
# [157 rows x 4 columns]

# %%
#To display only the rows that have missing data in Ozone column, and display columns 'Ozone','Temp_F','Temp_F_Bin','Ozone_Full'
data[data[['Ozone_Full','Ozone','Temp_F_Bin']].isnull().any(axis=1)][['Ozone','Temp_F','Temp_F_Bin','Ozone_Full']]
# Out:
#      Ozone  Temp_F Temp_F_Bin  Ozone_Full
# 4      NaN      56      55-60   11.000000
# 9      NaN      69      65-70   24.466667
# 24     NaN      57      55-60   11.000000
# 25     NaN      58      55-60   11.000000
# 26     NaN      57      55-60   11.000000
# 31     NaN      78      75-80   32.857143
# 32     NaN      74      70-75   16.933333
# 33     NaN      67      65-70   24.466667
# 34     NaN      84      80-85   49.074074
# 35     NaN      85      80-85   49.074074
# 36     NaN      79      75-80   32.857143
# 38     NaN      87      85-90   73.176471
# 41     NaN      93      90-95   91.875000
# 42     NaN      92      90-95   91.875000
# 44     NaN      80      75-80   32.857143
# 45     NaN      79      75-80   32.857143
# 51     NaN      77      75-80   32.857143
# 52     NaN      76      75-80   32.857143
# 53     NaN      76      75-80   32.857143
# 54     NaN      76      75-80   32.857143
# 55     NaN      75      70-75   16.933333
# ...

# %%
#We will drop 'Ozone' column because we created a new column 'Ozone Full' which has all the replacements for missing data in Ozone
data.drop('Ozone',axis=1,inplace=True)
#We will drop 'Temp_F_Bin' column as it was created only for missing value imputation
data.drop('Temp_F_Bin',axis=1,inplace=True)
#We are renaming 'Ozone Full' column as 'Ozone'
data.rename({'Ozone_Full':'Ozone'},axis=1,inplace=True)
data
# Out:
# <ipython-input-63-27aac06a5ed7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('Ozone',axis=1,inplace=True)
# <ipython-input-63-27aac06a5ed7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('Temp_F_Bin',axis=1,inplace=True)
# <ipython-input-63-27aac06a5ed7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename({'Ozone_Full':'Ozone'},axis=1,inplace=True)
# ...

# %%
data.isnull().sum()
# Out:
# Solar_Radiation    0
# Wind               0
# Month              0
# Day                0
# Temp_F             0
# Weather            3
# Date               0
# Weekday            0
# Month_Words        0
# Ozone              0
# dtype: int64

# %%
data.groupby('Weather')[['Temp_F', 'Wind', 'Solar_Radiation','Ozone']].mean()
# Out:
#             Temp_F       Wind  Solar_Radiation      Ozone
# Weather
# C        77.734694   9.783673       192.795918  44.553607
# PS       76.872340   9.908511       174.872340  41.418141
# S        78.120690  10.020690       193.568966  38.938538

# %%
data[data[['Weather']].isnull().any(axis=1)]
# Out:
#     Solar_Radiation  Wind  Month  Day  Temp_F Weather       Date    Weekday  \
# 87             82.0  12.0      7   27      86     NaN 2010-07-27    Tuesday
# 93             24.0  13.8      8    2      81     NaN 2010-08-02     Monday
# 95            199.0   6.9      8    4      86     NaN 2010-08-04  Wednesday
#
#    Month_Words  Ozone
# 87        July   52.0
# 93      August    9.0
# 95      August   78.0

# %%
data['Weather'].mode()

# %%
data['Weather']=data['Weather'].fillna('S')
# Out:
# <ipython-input-74-be676cd8ba9e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Weather']=data['Weather'].fillna('S')

# %%
data.isnull().sum()

# %%
#data_cleaned=pd.concat([data_cleaned,obj_columns],axis=1)

# %% [markdown]
# # Scatter plot and Correlation analysis

# %%
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
sns.pairplot(data)

# %%
#Correlation
data.loc[:,['Solar_Radiation','Wind', 'Month', 'Day', 'Temp_F', 'Ozone']].corr()
# Out:
#                  Solar_Radiation      Wind     Month       Day    Temp_F  \
# Solar_Radiation         1.000000 -0.057709 -0.083788 -0.156243  0.256994
# Wind                   -0.057709  1.000000 -0.170328  0.029900 -0.441228
# Month                  -0.083788 -0.170328  1.000000  0.041438  0.408060
# Day                    -0.156243  0.029900  0.041438  1.000000 -0.122787
# Temp_F                  0.256994 -0.441228  0.408060 -0.122787  1.000000
# Ozone                   0.320703 -0.513543  0.177637 -0.068488  0.721248
#
#                     Ozone
# Solar_Radiation  0.320703
# Wind            -0.513543
# Month            0.177637
# Day             -0.068488
# Temp_F           0.721248
# Ozone            1.000000

# %% [markdown]
# Correlation is always between -1 to +1
#
# -1 to -0.5 & +0.5 to +1 is strong correlationship
#
# -0.5 to -0.15 & +0.15 to 0.5 is moderate correlationship
#
# Values very close to 0 indicate no correlationship
#
# # -1 ----------- -0.5 ----------- 0 ----------- 0.5 ----------- 1

# %%
#import pandas as pd
#data.to_csv('/content/sample_data/cleaned_data.csv')

# %%
from scipy import stats
month_weather= pd.crosstab(data['Month'], data['Weather'])
month_weather
# Out:
# Weather   C  PS   S
# Month
# 5        11   9  12
# 6         9   9  12
# 7        11   8  11
# 8        10   8  11
# 9         8  13  12

# %%
#Null Hypothesis - Month & Weather are not statistally correlated.
#Alternate Hypothesis - Month & Weather are statistally correlated.
stats.chi2_contingency(month_weather)
# Out:
# Chi2ContingencyResult(statistic=2.18750570737061, pvalue=0.9747169973233103, dof=8, expected_freq=array([[10.18181818,  9.76623377, 12.05194805],
#        [ 9.54545455,  9.15584416, 11.2987013 ],
#        [ 9.54545455,  9.15584416, 11.2987013 ],
#        [ 9.22727273,  8.85064935, 10.92207792],
#        [10.5       , 10.07142857, 12.42857143]]))

# %% [markdown]
# # Transformations
#
# ### Creating dummy variable for Weather column
#
# ### Dummy variable creation OR One Hot Encoding

# %%
data
# Out:
#      Solar_Radiation  Wind  Month  Day  Temp_F Weather       Date    Weekday  \
# 0              190.0   7.4      5    1      67       S 2010-05-01   Saturday
# 1              118.0   8.0      5    2      72       C 2010-05-02     Sunday
# 2              149.0  12.6      5    3      74      PS 2010-05-03     Monday
# 3              313.0  11.5      5    4      62       S 2010-05-04    Tuesday
# 4              199.0  14.3      5    5      56       S 2010-05-05  Wednesday
# ..               ...   ...    ...  ...     ...     ...        ...        ...
# 152            223.0  11.5      9   30      68       S 2010-09-30   Thursday
# 153            190.0   7.4      5    1      67       C 2010-05-01   Saturday
# 154            193.0   6.9      9   26      70      PS 2010-09-26     Sunday
# 155            145.0  13.2      9   27      77       S 2010-09-27     Monday
# 157            131.0   8.0      9   29      76       C 2010-09-29  Wednesday
#
#     Month_Words      Ozone
# ...

# %%
weather_dummies=pd.get_dummies(data,columns=['Weather'], dtype='int')
data
# Out:
#      Solar_Radiation  Wind  Month  Day  Temp_F Weather       Date    Weekday  \
# 0              190.0   7.4      5    1      67       S 2010-05-01   Saturday
# 1              118.0   8.0      5    2      72       C 2010-05-02     Sunday
# 2              149.0  12.6      5    3      74      PS 2010-05-03     Monday
# 3              313.0  11.5      5    4      62       S 2010-05-04    Tuesday
# 4              199.0  14.3      5    5      56       S 2010-05-05  Wednesday
# ..               ...   ...    ...  ...     ...     ...        ...        ...
# 152            223.0  11.5      9   30      68       S 2010-09-30   Thursday
# 153            190.0   7.4      5    1      67       C 2010-05-01   Saturday
# 154            193.0   6.9      9   26      70      PS 2010-09-26     Sunday
# 155            145.0  13.2      9   27      77       S 2010-09-27     Monday
# 157            131.0   8.0      9   29      76       C 2010-09-29  Wednesday
#
#     Month_Words      Ozone
# ...

# %%
weather_dummies['Weather'] = data['Weather']
weather_dummies
# Out:
#      Solar_Radiation  Wind  Month  Day  Temp_F       Date    Weekday  \
# 0              190.0   7.4      5    1      67 2010-05-01   Saturday
# 1              118.0   8.0      5    2      72 2010-05-02     Sunday
# 2              149.0  12.6      5    3      74 2010-05-03     Monday
# 3              313.0  11.5      5    4      62 2010-05-04    Tuesday
# 4              199.0  14.3      5    5      56 2010-05-05  Wednesday
# ..               ...   ...    ...  ...     ...        ...        ...
# 152            223.0  11.5      9   30      68 2010-09-30   Thursday
# 153            190.0   7.4      5    1      67 2010-05-01   Saturday
# 154            193.0   6.9      9   26      70 2010-09-26     Sunday
# 155            145.0  13.2      9   27      77 2010-09-27     Monday
# 157            131.0   8.0      9   29      76 2010-09-29  Wednesday
#
#     Month_Words      Ozone  Weather_C  Weather_PS  Weather_S Weather
# 0           May  41.000000          0           0          1       S
# ...

# %%
#weather_dummies['Weather_C'] = weather_dummies['Weather_C'].replace({True:1,False:0})
#weather_dummies['Weather_PS'] = weather_dummies['Weather_PS'].replace({True:1,False:0})
#weather_dummies['Weather_S'] = weather_dummies['Weather_S'].replace({True:1,False:0})
#weather_dummies['Weather'] = data['Weather']
#weather_dummies

#Instead of replace, we can also use the commands mentioned below:
'''
weather_dummies['Weather_C'] = weather_dummies['Weather_C'].astype('int')
weather_dummies['Weather_PS'] = weather_dummies['Weather_PS'].astype('int')
weather_dummies['Weather_S'] = weather_dummies['Weather_S'].astype('int')
'''
# Out:
# "\nweather_dummies['Weather_C'] = weather_dummies['Weather_C'].astype('int')\nweather_dummies['Weather_PS'] = weather_dummies['Weather_PS'].astype('int')\nweather_dummies['Weather_S'] = weather_dummies['Weather_S'].astype('int')\n"

# %% [markdown]
# # Normalization of the data
# # Scaling of Data

# %%
#print('Minimum Value of Solar',data['Solar'].min())
#print('Maximum Value of Solar',data['Solar'].max())
#print('Mean Value of Solar',data['Solar'].mean())
#print('Std Deviation Value of Solar',data['Solar'].std())

# %%
data.describe()

# %%
data
# Out:
#      Solar_Radiation  Wind  Month  Day  Temp_F Weather       Date    Weekday  \
# 0              190.0   7.4      5    1      67       S 2010-05-01   Saturday
# 1              118.0   8.0      5    2      72       C 2010-05-02     Sunday
# 2              149.0  12.6      5    3      74      PS 2010-05-03     Monday
# 3              313.0  11.5      5    4      62       S 2010-05-04    Tuesday
# 4              199.0  14.3      5    5      56       S 2010-05-05  Wednesday
# ..               ...   ...    ...  ...     ...     ...        ...        ...
# 152            223.0  11.5      9   30      68       S 2010-09-30   Thursday
# 153            190.0   7.4      5    1      67       C 2010-05-01   Saturday
# 154            193.0   6.9      9   26      70      PS 2010-09-26     Sunday
# 155            145.0  13.2      9   27      77       S 2010-09-27     Monday
# 157            131.0   8.0      9   29      76       C 2010-09-29  Wednesday
#
#     Month_Words      Ozone
# ...

# %%
data.columns
# Out:
# Index(['Solar_Radiation', 'Wind', 'Month', 'Day', 'Temp_F', 'Weather', 'Date',
#        'Weekday', 'Month_Words', 'Ozone'],
#       dtype='object')

# %%
#Scaling is required only for numerical columns, so we created a subset data having only numerical columns from original data
data_numerical= data[['Solar_Radiation','Wind', 'Month', 'Day', 'Temp_F','Ozone']]
data_numerical
# Out:
#      Solar_Radiation  Wind  Month  Day  Temp_F      Ozone
# 0              190.0   7.4      5    1      67  41.000000
# 1              118.0   8.0      5    2      72  36.000000
# 2              149.0  12.6      5    3      74  12.000000
# 3              313.0  11.5      5    4      62  18.000000
# 4              199.0  14.3      5    5      56  11.000000
# ..               ...   ...    ...  ...     ...        ...
# 152            223.0  11.5      9   30      68  20.000000
# 153            190.0   7.4      5    1      67  41.000000
# 154            193.0   6.9      9   26      70  30.000000
# 155            145.0  13.2      9   27      77  32.857143
# 157            131.0   8.0      9   29      76  18.000000
#
# [157 rows x 6 columns]

# %% [markdown]
# # MinMax Scalar
#
# (Data_Value - Minimum Value) / Range of the Data (Maximum Value - Minimum Value)

# %%
#MinMax Scalar
data['Solar_Scaled'] = (data['Solar_Radiation'] - min(data['Solar_Radiation'])) / (max(data['Solar_Radiation']) - min(data['Solar_Radiation']))
data
# Out:
# <ipython-input-98-f98218cde57e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Solar_Scaled'] = (data['Solar_Radiation'] - min(data['Solar_Radiation'])) / (max(data['Solar_Radiation']) - min(data['Solar_Radiation']))
#      Solar_Radiation  Wind  Month  Day  Temp_F Weather       Date    Weekday  \
# 0              190.0   7.4      5    1      67       S 2010-05-01   Saturday
# 1              118.0   8.0      5    2      72       C 2010-05-02     Sunday
# 2              149.0  12.6      5    3      74      PS 2010-05-03     Monday
# 3              313.0  11.5      5    4      62       S 2010-05-04    Tuesday
# 4              199.0  14.3      5    5      56       S 2010-05-05  Wednesday
# ...

# %%
#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(data_numerical)
rescaledX
# Out:
# array([[0.56, 0.3 , 0.  , 0.  , 0.27, 0.24],
#        [0.34, 0.33, 0.  , 0.03, 0.39, 0.21],
#        [0.43, 0.57, 0.  , 0.07, 0.44, 0.07],
#        [0.94, 0.52, 0.  , 0.1 , 0.15, 0.1 ],
#        [0.59, 0.66, 0.  , 0.13, 0.  , 0.06],
#        [0.59, 0.69, 0.  , 0.17, 0.24, 0.16],
#        [0.89, 0.36, 0.  , 0.2 , 0.22, 0.13],
#        [0.28, 0.64, 0.  , 0.23, 0.07, 0.11],
#        [0.04, 0.97, 0.  , 0.27, 0.12, 0.04],
#        [0.57, 0.36, 0.  , 0.3 , 0.32, 0.14],
#        [0.59, 0.27, 0.  , 0.33, 0.44, 0.04],
#        [0.76, 0.42, 0.  , 0.37, 0.32, 0.09],
#        [0.87, 0.39, 0.  , 0.4 , 0.24, 0.06],
#        [0.82, 0.48, 0.  , 0.43, 0.29, 0.08],
#        [0.18, 0.61, 0.  , 0.47, 0.05, 0.1 ],
#        [1.  , 0.52, 0.  , 0.5 , 0.2 , 0.08],
#        [0.92, 0.54, 0.  , 0.53, 0.24, 0.2 ],
#        [0.22, 0.88, 0.  , 0.57, 0.02, 0.03],
#        [0.96, 0.52, 0.  , 0.6 , 0.29, 0.17],
#        [0.11, 0.42, 0.  , 0.63, 0.15, 0.06],
#        [0.  , 0.42, 0.  , 0.67, 0.07, 0.  ],
# ...

# %%
#To transform the numerical columns to scaled values
#array1=data_numerical.values
#array1
# Out:
# array([[190.        ,   7.4       ,   5.        , ...,  67.        ,
#          41.        ,   0.55963303],
#        [118.        ,   8.        ,   5.        , ...,  72.        ,
#          36.        ,   0.33944954],
#        [149.        ,  12.6       ,   5.        , ...,  74.        ,
#          12.        ,   0.43425076],
#        ...,
#        [193.        ,   6.9       ,   9.        , ...,  70.        ,
#          30.        ,   0.56880734],
#        [145.        ,  13.2       ,   9.        , ...,  77.        ,
#          32.85714286,   0.42201835],
#        [131.        ,   8.        ,   9.        , ...,  76.        ,
#          18.        ,   0.37920489]])

# %%
#transformed data
set_printoptions(precision=2)
print(rescaledX)
# Out:
# [[0.56 0.3  0.   0.   0.27 0.24]
#  [0.34 0.33 0.   0.03 0.39 0.21]
#  [0.43 0.57 0.   0.07 0.44 0.07]
#  [0.94 0.52 0.   0.1  0.15 0.1 ]
#  [0.59 0.66 0.   0.13 0.   0.06]
#  [0.59 0.69 0.   0.17 0.24 0.16]
#  [0.89 0.36 0.   0.2  0.22 0.13]
#  [0.28 0.64 0.   0.23 0.07 0.11]
#  [0.04 0.97 0.   0.27 0.12 0.04]
#  [0.57 0.36 0.   0.3  0.32 0.14]
#  [0.59 0.27 0.   0.33 0.44 0.04]
#  [0.76 0.42 0.   0.37 0.32 0.09]
#  [0.87 0.39 0.   0.4  0.24 0.06]
#  [0.82 0.48 0.   0.43 0.29 0.08]
#  [0.18 0.61 0.   0.47 0.05 0.1 ]
#  [1.   0.52 0.   0.5  0.2  0.08]
#  [0.92 0.54 0.   0.53 0.24 0.2 ]
#  [0.22 0.88 0.   0.57 0.02 0.03]
#  [0.96 0.52 0.   0.6  0.29 0.17]
#  [0.11 0.42 0.   0.63 0.15 0.06]
#  [0.   0.42 0.   0.67 0.07 0.  ]
#  [0.96 0.78 0.   0.7  0.41 0.06]
#  [0.06 0.42 0.   0.73 0.12 0.02]
#  [0.26 0.54 0.   0.77 0.12 0.19]
#  [0.18 0.78 0.   0.8  0.02 0.06]
#  [0.79 0.69 0.   0.83 0.05 0.06]
#  [0.59 0.33 0.   0.87 0.02 0.06]
#  [0.02 0.54 0.   0.9  0.27 0.13]
# ...

# %%
data1 = pd.DataFrame(rescaledX, columns=list(data_numerical.columns))
data1
# Out:
#      Solar_Radiation      Wind  Month       Day    Temp_F     Ozone
# 0           0.559633  0.300000    0.0  0.000000  0.268293  0.239521
# 1           0.339450  0.331579    0.0  0.033333  0.390244  0.209581
# 2           0.434251  0.573684    0.0  0.066667  0.439024  0.065868
# 3           0.935780  0.515789    0.0  0.100000  0.146341  0.101796
# 4           0.587156  0.663158    0.0  0.133333  0.000000  0.059880
# ..               ...       ...    ...       ...       ...       ...
# 152         0.660550  0.515789    1.0  0.966667  0.292683  0.113772
# 153         0.559633  0.300000    0.0  0.000000  0.268293  0.239521
# 154         0.568807  0.273684    1.0  0.833333  0.341463  0.173653
# 155         0.422018  0.605263    1.0  0.866667  0.512195  0.190761
# 156         0.379205  0.331579    1.0  0.933333  0.487805  0.101796
#
# [157 rows x 6 columns]

# %%
data_final = pd.concat([data,data1], axis= 1)
data_final

# %% [markdown]
# # StandardScaler
#
# (Data Value - Mean of the column) / Stdev of the Column

# %%
data
# Out:
#      Solar_Radiation  Wind  Month  Day  Temp_F Weather       Date    Weekday  \
# 0              190.0   7.4      5    1      67       S 2010-05-01   Saturday
# 1              118.0   8.0      5    2      72       C 2010-05-02     Sunday
# 2              149.0  12.6      5    3      74      PS 2010-05-03     Monday
# 3              313.0  11.5      5    4      62       S 2010-05-04    Tuesday
# 4              199.0  14.3      5    5      56       S 2010-05-05  Wednesday
# ..               ...   ...    ...  ...     ...     ...        ...        ...
# 152            223.0  11.5      9   30      68       S 2010-09-30   Thursday
# 153            190.0   7.4      5    1      67       C 2010-05-01   Saturday
# 154            193.0   6.9      9   26      70      PS 2010-09-26     Sunday
# 155            145.0  13.2      9   27      77       S 2010-09-27     Monday
# 157            131.0   8.0      9   29      76       C 2010-09-29  Wednesday
#
#     Month_Words      Ozone  Solar_Scaled
# ...

# %%
data.drop('Solar_Scaled', axis=1,inplace=True)
# Out:
# <ipython-input-104-127908e26a9d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('Solar_Scaled', axis=1,inplace=True)

# %%
#Scaling is required only for numerical columns, so we created a subset data having only numerical columns from original data
data_numerical= data[['Solar_Radiation','Wind', 'Month', 'Day', 'Temp_F','Ozone']]
data_numerical
# Out:
#      Solar_Radiation  Wind  Month  Day  Temp_F      Ozone
# 0              190.0   7.4      5    1      67  41.000000
# 1              118.0   8.0      5    2      72  36.000000
# 2              149.0  12.6      5    3      74  12.000000
# 3              313.0  11.5      5    4      62  18.000000
# 4              199.0  14.3      5    5      56  11.000000
# ..               ...   ...    ...  ...     ...        ...
# 152            223.0  11.5      9   30      68  20.000000
# 153            190.0   7.4      5    1      67  41.000000
# 154            193.0   6.9      9   26      70  30.000000
# 155            145.0  13.2      9   27      77  32.857143
# 157            131.0   8.0      9   29      76  18.000000
#
# [157 rows x 6 columns]

# %%
data['Solar_Scaled'] = (data['Solar_Radiation'] - data['Solar_Radiation'].mean()) / data['Solar_Radiation'].std()
data
# Out:
# <ipython-input-108-3d19debdb5c7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Solar_Scaled'] = (data['Solar_Radiation'] - data['Solar_Radiation'].mean()) / data['Solar_Radiation'].std()
#      Solar_Radiation  Wind  Month  Day  Temp_F Weather       Date    Weekday  \
# 0              190.0   7.4      5    1      67       S 2010-05-01   Saturday
# 1              118.0   8.0      5    2      72       C 2010-05-02     Sunday
# 2              149.0  12.6      5    3      74      PS 2010-05-03     Monday
# 3              313.0  11.5      5    4      62       S 2010-05-04    Tuesday
# 4              199.0  14.3      5    5      56       S 2010-05-05  Wednesday
# ...

# %%
data.drop('Solar_Scaled', axis=1,inplace=True)
data
# Out:
# <ipython-input-109-8c23c20c6f16>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('Solar_Scaled', axis=1,inplace=True)
#      Solar_Radiation  Wind  Month  Day  Temp_F Weather       Date    Weekday  \
# 0              190.0   7.4      5    1      67       S 2010-05-01   Saturday
# 1              118.0   8.0      5    2      72       C 2010-05-02     Sunday
# 2              149.0  12.6      5    3      74      PS 2010-05-03     Monday
# 3              313.0  11.5      5    4      62       S 2010-05-04    Tuesday
# 4              199.0  14.3      5    5      56       S 2010-05-05  Wednesday
# ..               ...   ...    ...  ...     ...     ...        ...        ...
# 152            223.0  11.5      9   30      68       S 2010-09-30   Thursday
# ...

# %%
#scaler = StandardScaler().fit(array1)
#rescaledX = scaler.transform(array1)

# %%
# Standardize data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
rescaledX=scaler.fit_transform(data_numerical)
rescaledX
set_printoptions(precision=2,suppress=True)
rescaledX
# Out:
# array([[ 0.05, -0.72, -1.41, -1.67, -1.15, -0.02],
#        [-0.78, -0.55, -1.41, -1.56, -0.61, -0.18],
#        [-0.43,  0.76, -1.41, -1.45, -0.4 , -0.97],
#        [ 1.46,  0.45, -1.41, -1.33, -1.68, -0.77],
#        [ 0.15,  1.25, -1.41, -1.22, -2.32, -1.  ],
#        [ 0.15,  1.42, -1.41, -1.11, -1.25, -0.44],
#        [ 1.3 , -0.38, -1.41, -1.  , -1.36, -0.61],
#        [-1.  ,  1.11, -1.41, -0.89, -2.  , -0.74],
#        [-1.92,  2.91, -1.41, -0.77, -1.79, -1.1 ],
#        [ 0.09, -0.38, -1.41, -0.66, -0.93, -0.56],
#        [ 0.15, -0.87, -1.41, -0.55, -0.4 , -1.13],
#        [ 0.81, -0.07, -1.41, -0.44, -0.93, -0.84],
#        [ 1.2 , -0.21, -1.41, -0.33, -1.25, -1.  ],
#        [ 1.01,  0.28, -1.41, -0.22, -1.04, -0.9 ],
#        [-1.39,  0.94, -1.41, -0.1 , -2.11, -0.77],
#        [ 1.71,  0.45, -1.41,  0.01, -1.47, -0.9 ],
#        [ 1.39,  0.59, -1.41,  0.12, -1.25, -0.25],
#        [-1.24,  2.42, -1.41,  0.23, -2.21, -1.16],
# ...

# %%
data1 = pd.DataFrame(rescaledX, columns=list(data_numerical.columns))
data1
# Out:
#      Solar_Radiation      Wind     Month       Day    Temp_F     Ozone
# 0           0.046394 -0.724079 -1.412198 -1.668937 -1.146116 -0.018766
# 1          -0.783413 -0.552356 -1.412198 -1.557152 -0.612802 -0.182061
# 2          -0.426135  0.764184 -1.412198 -1.445367 -0.399476 -0.965874
# 3           1.463982  0.449359 -1.412198 -1.333583 -1.679431 -0.769921
# 4           0.150120  1.250731 -1.412198 -1.221798 -2.319408 -0.998533
# ..               ...       ...       ...       ...       ...       ...
# 152         0.426722  0.449359  1.385469  1.572816 -1.039454 -0.704603
# 153         0.046394 -0.724079 -1.412198 -1.668937 -1.146116 -0.018766
# 154         0.080969 -0.867181  1.385469  1.125678 -0.826128 -0.378014
# 155        -0.472236  0.935906  1.385469  1.237462 -0.079488 -0.284703
# 156        -0.633587 -0.552356  1.385469  1.461032 -0.186150 -0.769921
#
# [157 rows x 6 columns]

# %%
data_final = pd.concat([data,data1], axis= 1)
data_final
# Out:
#      Solar_Radiation  Wind  Month   Day  Temp_F Weather       Date    Weekday  \
# 0              190.0   7.4    5.0   1.0    67.0       S 2010-05-01   Saturday
# 1              118.0   8.0    5.0   2.0    72.0       C 2010-05-02     Sunday
# 2              149.0  12.6    5.0   3.0    74.0      PS 2010-05-03     Monday
# 3              313.0  11.5    5.0   4.0    62.0       S 2010-05-04    Tuesday
# 4              199.0  14.3    5.0   5.0    56.0       S 2010-05-05  Wednesday
# ..               ...   ...    ...   ...     ...     ...        ...        ...
# 153            190.0   7.4    5.0   1.0    67.0       C 2010-05-01   Saturday
# 154            193.0   6.9    9.0  26.0    70.0      PS 2010-09-26     Sunday
# 155            145.0  13.2    9.0  27.0    77.0       S 2010-09-27     Monday
# 157            131.0   8.0    9.0  29.0    76.0       C 2010-09-29  Wednesday
# 156              NaN   NaN    NaN   NaN     NaN     NaN        NaT        NaN
#
# ...

# %% [markdown]
# # Speed up the EDA process

# %%
#pip (preferred installer program)
#!pip install pandas_profiling
#!pip install sweetviz

# %%
#pip install pandas_profiling

# %%
#import pandas_profiling as pp
#EDA_report= pp.ProfileReport(data)
#EDA_report

# %%
#To create an HTML format report
#EDA_report.to_file(output_file='report.html')

# %%
#sweet_report = sv.analyze(data)
#sweet_report.show_html('weather_report.html')

# %%
# import pandas
import pandas as pd

# create data frame
df = pd.DataFrame({'First Name': ["Mukul", "Rohan", "Mayank",
                                  "Vedansh", "Krishna"],

                   'Location': ["Saharanpur", "Rampur", "Agra",
                                "Saharanpur", "Noida"],

                   'Pay': [56000.0, 55000.0, 61000.0, 45000.0, 62000.0]})

# print original data frame
display(df)

# create a dictionary
# key = old name
# value = new name
dict = {'First Name': 'Name',
        'Location': 'City',
        'Pay': 'Salary'}

# call rename () method
df.rename(columns=dict,
          inplace=True)

# print Data frame after rename columns
display(df)

# %%
from google.colab import files
uploaded=files.upload()

# %%
data=pd.read_csv('data_clean.csv')
data

# %%
weather_C=data[data['Weather']=='C']['Temp']
weather_C

# %%
weather_S=data[data['Weather']=='S']['Temp']
weather_S

# %%
weather_PS=data[data['Weather']=='PS']['Temp']
weather_PS

# %%
from scipy import stats
stats.f_oneway(weather_C,weather_S,weather_PS)

# %%
#data['Weather']=data['Weather'].astype('category')
#data['Wind']=data['Wind'].astype('int64')

# %%
#data['date']=pd.to_datetime(data['Year'] + "/" + data['Month'] + "/" + data['Day'])
#data

# %%
#Solar Outliers
series = data['Solar']
print(data.boxplot(column=['Solar'],grid=True))
print(series.describe())
#Quartile 1
print(data['Solar'].describe())
Q1=data['Solar'].quantile(0.25)
print('Quartile 1 : ',Q1)
#Quartile 3
Q3=data['Solar'].quantile(0.75)
print('Quartile 3 : ',Q3)
#Interquartile Range
IQR= Q3 - Q1
print('Inter-Quartile Range : ',IQR)
#Upper Limit of Solar
UL = Q3 + (1.5 * IQR)
print('Upper Limit : ',UL)
#Lower Limit of Solar
LL = Q1 - (1.5 * IQR)
print('Lower Limit : ', LL)
Solar_Outliers=data[(data['Solar'] > UL) | (data['Solar'] < LL)]
Solar_Outliers
